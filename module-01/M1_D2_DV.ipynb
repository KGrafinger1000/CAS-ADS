# %% [markdown]
# Notebook 1, Module 1, Data and Data Management, CAS Applied Data Science, 2024-08-22, A. Mühlemann, University of Bern. (based on the template by S. Haug)

# %% [markdown]
# # 1. Visualisation of Data - Examples
#
# **Learning outcomes:**
#
# Participants will be able to make good data science plots, with praxis on
# - plot line charts from series and dataframes
# - plot histograms
#   - understand the effect of binning
# - plot scatter plots
# - plot box plots
# - plot error bars
# - formatting of plots
# - geoplotting
#
# **Introduction Slides**
# - https://drive.google.com/file/d/12hehfcdVOR0lpemy5Y-84EspCiOjr8e9/view?usp=sharing
#
# **Further sources**
# - Python: https://pandas.pydata.org/pandas-docs/stable/visualization.html
# - https://jakevdp.github.io/PythonDataScienceHandbook/04.00-introduction-to-matplotlib.html
# - Get inspired here : https://matplotlib.org/gallery/index.html
#
# Here you have examples on plotting possibilities with pandas. They make data science plotting very easy and fast. However, you may have special needs that are not supported. Then you can use the underlaying plotting module **matplotlib**.
#
# Plotting is an art and you can spend enourmous amounts of time doing plotting. There are many types of plots. You may invent your own type. We only show some examples and point out some important things. If you need to go further, you have to work indepentently.
#
# Some vocabulary and plots are only understandable with corresponding statistics background. This is part of module 2.

# %% [markdown]
# ## 0. Load the modules

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## 1. Line charts
# Since line charts are for time series we use a time series data set for this visualization. On ILIAS you can find a data set called *garbage.csv* containing the garbage of in kg/inhabitant in Liestal, Basel, from 2017-2024 divided into different types of garbage. We first need to upload this data set to python and make a dataframe out of it.

# %%
# ich verwende VSstudio- deshalb von meinem pc reinladen
#from google.colab import files
#uploaded = files.upload()

# Upload the local data file to colab
data_garbage = pd.read_csv("./datasets/garbage.csv", sep=";")

# Display first few rows
data_garbage.head()
# Out:
#    Jahr Gemeinde                Kategorie       Einheit    Wert
# 0  2017  Liestal                     Glas  kg pro Einw.  28.670
# 1  2017  Liestal                 Gruengut  kg pro Einw.  65.583
# 2  2017  Liestal  Hauskehricht + Sperrgut  kg pro Einw.  18.820
# 3  2017  Liestal              Kunststoffe  kg pro Einw.   0.000
# 4  2017  Liestal                     Oele  kg pro Einw.   0.010

# %%
#garbage = pd.read_csv('garbage.csv', sep=";")
#garbage
# Out:
#     Jahr Gemeinde                Kategorie       Einheit        Wert
# 0   2017  Liestal                     Glas  kg pro Einw.   28.670000
# 1   2017  Liestal                 Gruengut  kg pro Einw.   65.583000
# 2   2017  Liestal  Hauskehricht + Sperrgut  kg pro Einw.   18.820000
# 3   2017  Liestal              Kunststoffe  kg pro Einw.    0.000000
# 4   2017  Liestal                     Oele  kg pro Einw.    0.010000
# 5   2017  Liestal          Papier + Karton  kg pro Einw.   51.260000
# 6   2017  Liestal          Uebrige Metalle  kg pro Einw.    0.000000
# 7   2017  Liestal         Weissblech + Alu  kg pro Einw.    2.010000
# 8   2018  Liestal                     Glas  kg pro Einw.   29.045658
# 9   2018  Liestal                 Gruengut  kg pro Einw.   63.627199
# 10  2018  Liestal  Hauskehricht + Sperrgut  kg pro Einw.  187.324770
# 11  2018  Liestal              Kunststoffe  kg pro Einw.    0.000000
# 12  2018  Liestal                     Oele  kg pro Einw.    0.023178
# 13  2018  Liestal          Papier + Karton  kg pro Einw.   49.901564
# 14  2018  Liestal          Uebrige Metalle  kg pro Einw.    0.000000
# 15  2018  Liestal         Weissblech + Alu  kg pro Einw.    1.947082
# 16  2019  Liestal                     Glas  kg pro Einw.   28.732751
# 17  2019  Liestal                 Gruengut  kg pro Einw.   69.995146
# 18  2019  Liestal  Hauskehricht + Sperrgut  kg pro Einw.  183.456071
# 19  2019  Liestal              Kunststoffe  kg pro Einw.    0.000000
# 20  2019  Liestal                     Oele  kg pro Einw.    0.034117
# 21  2019  Liestal          Papier + Karton  kg pro Einw.   44.338811
# 22  2019  Liestal          Uebrige Metalle  kg pro Einw.    0.000000
# 23  2019  Liestal         Weissblech + Alu  kg pro Einw.    1.794605
# 24  2020  Liestal                     Glas  kg pro Einw.   29.885219
# 25  2020  Liestal                 Gruengut  kg pro Einw.   76.078942
# 26  2020  Liestal  Hauskehricht + Sperrgut  kg pro Einw.  182.826698
# 27  2020  Liestal              Kunststoffe  kg pro Einw.    0.000000
# 28  2020  Liestal                     Oele  kg pro Einw.    0.000000
# 29  2020  Liestal          Papier + Karton  kg pro Einw.   42.799973
# 30  2020  Liestal          Uebrige Metalle  kg pro Einw.    0.475570
# 31  2020  Liestal         Weissblech + Alu  kg pro Einw.    1.986569
# 32  2021  Liestal                     Glas  kg pro Einw.   24.600000
# 33  2021  Liestal                 Gruengut  kg pro Einw.   78.700000
# 34  2021  Liestal  Hauskehricht + Sperrgut  kg pro Einw.  181.600000
# 35  2021  Liestal              Kunststoffe  kg pro Einw.    0.000000
# 36  2021  Liestal                     Oele  kg pro Einw.    0.200000
# 37  2021  Liestal          Papier + Karton  kg pro Einw.   46.900000
# 38  2021  Liestal          Uebrige Metalle  kg pro Einw.    0.000000
# 39  2021  Liestal         Weissblech + Alu  kg pro Einw.    2.000000
# 40  2022  Liestal                     Glas  kg pro Einw.   20.100000
# 41  2022  Liestal                 Gruengut  kg pro Einw.   62.300000
# 42  2022  Liestal  Hauskehricht + Sperrgut  kg pro Einw.  172.400000
# 43  2022  Liestal              Kunststoffe  kg pro Einw.    0.000000
# 44  2022  Liestal                     Oele  kg pro Einw.    0.000000
# 45  2022  Liestal          Papier + Karton  kg pro Einw.   42.000000
# 46  2022  Liestal          Uebrige Metalle  kg pro Einw.    0.400000
# 47  2022  Liestal         Weissblech + Alu  kg pro Einw.    1.900000
# 48  2023  Liestal                     Glas  kg pro Einw.   18.600000
# 49  2023  Liestal                 Gruengut  kg pro Einw.   59.300000
# 50  2023  Liestal  Hauskehricht + Sperrgut  kg pro Einw.  170.200000
# 51  2023  Liestal              Kunststoffe  kg pro Einw.    0.000000
# 52  2023  Liestal                     Oele  kg pro Einw.    0.100000
# 53  2023  Liestal          Papier + Karton  kg pro Einw.   39.500000
# 54  2023  Liestal          Uebrige Metalle  kg pro Einw.    0.300000
# 55  2023  Liestal         Weissblech + Alu  kg pro Einw.    1.900000

# %% [markdown]
# Let us now plot the time series of "Hauskehricht + Sperrgut"

# %%
# Plot using pandas' built-in plot function
household_rubbish = data_garbage[data_garbage['Kategorie']=='Hauskehricht + Sperrgut']
household_rubbish.plot(x='Jahr', y='Wert', kind='line', marker='o', linestyle='-', color='b', title='Household rubbis in kg/inhabitants')

# Customize the plot
plt.xlabel('Year')
plt.ylabel('kg/inhabitant')
plt.grid(True)

# Display the plot
plt.show()

# %% [markdown]
# ### Exercise
# What about a plot containing all garbage types?

# %%
for label, df_group in data_garbage.groupby('Kategorie'):
    plt.plot(df_group['Jahr'], df_group['Wert'], marker='o', linestyle='-', label=label)


plt.xlabel('Jahr')
plt.ylabel('kg/Einwohner')
plt.legend(title='Kategorien')
plt.title('Hausmüll pro Jahr pro Kategorie')

plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## 2. Histograms
# For this we use the dataset *sleep.csv* from yesterday.

# %%
url = 'https://github.com/KGzB/CAS-Applied-Data-Science/blob/master/Module-1/merged.csv?raw=true'
sleep = pd.read_csv(url, sep=',')
print(sleep.head(5))
# Out:
#    Unnamed: 0                 Species    BodyWt  BrainWt  NonDreaming  \
# 0           0         Africanelephant  6654.000   5712.0          NaN
# 1           1  Africangiantpouchedrat     1.000      6.6          6.3
# 2           2               ArcticFox     3.385     44.5          NaN
# 3           3    Arcticgroundsquirrel     0.920      5.7          NaN
# 4           4           Asianelephant  2547.000   4603.0          2.1
#
#    Dreaming  TotalSleep  LifeSpan  Gestation  Predation  Exposure  Danger
# 0       NaN         3.3      38.6      645.0          3         5       3
# 1       2.0         8.3       4.5       42.0          3         1       3
# 2       NaN        12.5      14.0       60.0          1         1       1
# 3       NaN        16.5       NaN       25.0          5         2       3
# 4       1.8         3.9      69.0      624.0          3         5       4

# %% [markdown]
# Plot a histogram for the lifespan of the mammals.

# %%
sleep['LifeSpan'].plot(kind="hist",fill=True,histtype='step',label='life span', color = "skyblue")
plt.show()

# %% [markdown]
# ### The effect of binning
#
# When data is binned (or sampled) the bin size effects the amount of counts in each bin. Counts fluctuate like a normal distribution for counts above about 20. So depending on your bin size, the same data may look differently.
#
# Hard binning (small bin size) may introduce pure statistical structures without any other meaning. This is then overfitting. Too big bin sizes may wipe out structures in the data (underfitting). If known, a bin size guided by the physical resolution of the sensor is close to optimal.
#
# Plot the same histograms with a different binning.

# %%
sleep['LifeSpan'].plot(kind="hist",fill=True,histtype='step',label='life span', color = "skyblue", bins=15)
plt.show()

# %%
sleep['LifeSpan'].plot(kind="hist",fill=True,histtype='step',label='life span', color = "skyblue", bins=50)
plt.show()

# %% [markdown]
# ### Exercise
# Plot a histogram for *Dreaming* and add *NonDreaming* to the same Histogram and add a legend.

# %%
dreaming = sleep["Dreaming"]
nondreaming = sleep["NonDreaming"]

# plotting first histogram
plt.hist(dreaming, fill= True, histtype='step',label='Dreaming', color = "skyblue", bins=30, alpha =0.5)

# plotting second histogram
plt.hist(nondreaming, fill= True, histtype='step',label='Non dreaming', color = "pink", bins=30, alpha =0.5)

# Showing the plot using plt.show()
plt.show()

# %%
# Lösung Anja
sleep['Dreaming'].plot(kind="hist",fill=True,histtype='step',label='Dreaming', alpha=0.5)
sleep['NonDreaming'].plot(kind="hist",fill=True,histtype='step',label='NonDreaming', alpha=0.5)
plt.legend()
plt.show()

# %% [markdown]
# Add label to the axes of the above plot

# %%
dreaming = sleep["Dreaming"]
nondreaming = sleep["NonDreaming"]

# plotting first histogram
plt.hist(dreaming, fill= True, histtype='step',label='Dreaming', color = "skyblue", bins=30, alpha =0.5)

# plotting second histogram
plt.hist(nondreaming, fill= True, histtype='step',label='Non dreaming', color = "pink", bins=30, alpha =0.5)

plt.xlabel('hours spent dreaming/not dreaming')
plt.ylabel('Frequency')
plt.legend(title='Sleep pattern')
plt.title('Schlafverhalten')
# Showing the plot using plt.show()
plt.show()

# %% [markdown]
# ## 3. Pie Charts
# Pie charts show the percentage on a whole.
# Let us look at the percentage an asian elephant spents dreaming.

# %%
sleep[sleep['Species'] == 'Asianelephant'][['NonDreaming', 'Dreaming']]
# Out:
#    NonDreaming  Dreaming
# 4          2.1       1.8

# %%
plt.pie(sleep[sleep['Species'] == 'Asianelephant'][['NonDreaming', 'Dreaming']].values.flatten(), labels=['NonDreaming', 'Dreaming'],
        autopct='%1.1f%%', colors = ['gold', 'lightcoral'])
plt.title('Dreaming / NonDreaming on asian elephant')
plt.show()

# %%
data1 = np.array([0.9, 0.1])
data2 = np.array([0.6, 0.4])

# create a figure with two subplots
fig, (ax1, ax2) = plt.subplots(1, 2)

# plot each pie chart in a separate subplot
ax1.pie(data1)
ax2.pie(data2)

plt.show()

# %% [markdown]
# ### Exercise
# Plot pie charts of three species next to each other

# %% [markdown]
# ein for loop ist hier die schlankeste lösung da sie der reihe nach abfragt bis die drei punkte abgefragt sind;

# %%
subset = sleep[4:7][['Species','NonDreaming', 'Dreaming']]
# Number of species
n_species = subset.shape[0]

# Create a figure and a set of subplots
fig, axs = plt.subplots(1, n_species, figsize=(15, 5))

# Loop through each species to create a pie chart
for i, species in enumerate(subset['Species']):
    sizes = subset[subset['Species'] == species][['NonDreaming', 'Dreaming']].values.flatten()
    axs[i].pie(sizes, labels=['NonDreaming', 'Dreaming'], autopct='%1.1f%%')
    axs[i].set_title(species)

# Display the pie charts
plt.tight_layout()
plt.show()

# %% [markdown]
# wenn ich selbst definieren will welche species ausgwählt wird dann muss ich es definieren und das [4:7] fällt raus

# %%
# Wir definieren explizit die Species, die geplottet werden sollen
species_list = ["Asianelephant", "Cat", "Cow"]

# Teil-DataFrame nur mit diesen Species
subset = sleep[sleep['Species'].isin(species_list)][['Species','NonDreaming','Dreaming']]

# Anzahl der Species
n_species = len(species_list)

# Figure + Subplots vorbereiten
fig, axs = plt.subplots(1, n_species, figsize=(15, 5))

# Falls nur 1 Achse zurückkommt, in Liste umwandeln (für Konsistenz)- das braucht es in meinem fall nicht;
if n_species == 1:
    axs = [axs]

# Schleife über die explizite Liste
for i, species in enumerate(species_list):
    sizes = subset[subset['Species'] == species][['NonDreaming', 'Dreaming']].values.flatten()
    axs[i].pie(sizes, labels=['NonDreaming', 'Dreaming'], autopct='%1.1f%%')
    axs[i].set_title(species)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 4. Scatter plots
#
# Scatter plots show how the data is distributed in two dimensions. They are good for finding (anti) correlations between two variables. Let us check whether there is a correlation between total sleep and the time spent dreaming.

# %%
sleep.plot(x='TotalSleep',y='Dreaming',kind="scatter",c='c')
plt.show()

# %% [markdown]
# ### Exercise
# Can you find a correlation between sleep and dreaming when you plot a different scatterplot for each level of exposure?

# %%
# Wir definieren explizit die Sleep-Level, die geplottet werden sollen
exposure_list = [1, 2, 3, 4, 5]

# Figure + Subplots vorbereiten
n_exposure = len(exposure_list)
fig, axs = plt.subplots(1, n_exposure, figsize=(15, 5), sharex=True, sharey=True)

# Schleife über die Liste der Levels
for i, exposure in enumerate(exposure_list):
    exposure_data = sleep[sleep['Exposure'] == exposure] #wichtig- überprüfen nach welchen Daten ich filtere!
    axs[i].scatter(exposure_data['TotalSleep'], exposure_data['Dreaming'], color="b")
    axs[i].set_title(f'Exposure = {exposure}')
    axs[i].set_xlabel('TotalSleep')
    axs[i].set_ylabel('Dreaming')

plt.tight_layout()
plt.show()

# %% [markdown]
# There are several other tools too. See https://pandas.pydata.org/pandas-docs/stable/visualization.html

# %% [markdown]
# ## 4. Box plots

# %% [markdown]
# A boxplot is a graphical representation that shows the distribution of a dataset by displaying its minimum, first quartile, median, third quartile, and maximum, along with any potential outliers. We will look at them in more detail in Module 2

# %%
sleep['TotalSleep'].plot.box()
plt.ylabel("Total sleep in hours")
plt.show()

# %% [markdown]
# ## 5. Plotting with error bars

# %% [markdown]
# There is no science without error bars, or better, uncertainties. The meaning of uncertainties is discussed in module 2. Here we only show by example  how to plot uncertainties.

# %% [markdown]
# Plotting with error bars is supported in DataFrame.plot() and Series.plot().
#
# Horizontal and vertical error bars can be supplied to the xerr and yerr keyword arguments to plot(). The error values can be specified using a variety of formats:
#
# - As a DataFrame or dict of errors with column names matching the columns attribute of the plotting DataFrame or matching the name attribute of the Series.
# - As a str indicating which of the columns of plotting DataFrame contain the error values.
# - As raw values (list, tuple, or np.ndarray). Must be the same length as the plotting DataFrame/Series.
#
# Asymmetrical error bars are also supported, however raw error values must be provided in this case. For a M length Series, a Mx2 array should be provided indicating lower and upper (or left and right) errors. For a MxN DataFrame, asymmetrical errors should be in a Mx2xN array.
#
# Here is an example using an error dataframe (symmetric uncertainties).

# %%
my_df   = pd.DataFrame([6,15,4,20,16,13]) # Some random data
my_df_e = (my_df)**0.5 # The error dataframe
my_df.plot(yerr=my_df_e)
plt.show()

# %% [markdown]
# ## 6. Formatting plots

# %% [markdown]
# Plots can easily be formatted with keywords. One can adjust colors, types of shading, lines, axes, legends, titles, etc. Some formatting has been exemplified above. More examples are in the documentation. https://pandas.pydata.org/pandas-docs/stable/visualization.html
#
# With the matplotlib module you are even more flexible. See https://matplotlib.org/gallery/index.html for inspirations.

# %% [markdown]
# ## 7. Summary
#
# - Do you remember three important plot types?
# - What can the binning of a histogram do to the interpretation of it?
# - Can you mention three important points to include in plots and their figure legends?

# %% [markdown]
# - scatterplot, boxplots, histograms
# - can help better interpret- the higher the bin number the smaller the bar in the histogram
# - units, header, axis labeling

# %% [markdown]
# ## 8. Plotting Geodata
#
# Often is very nice to visualise data on geographical maps. Fortunately people have written packages helpin us with that. This is an example how the geopandas package can be used.

# %% [markdown]
# First we need the so called shape files. They are provided by [swisstopo](https://www.swisstopo.admin.ch/en/geodata/landscape/boundaries3d.html/). For convenience there is a version on the CAS github repositoy.
#
# On Linux (colab is running linux) we get and unpack the files like this:

# %%
! wget https://github.com/sigvehaug/CAS-Applied-Data-Science/raw/master/Module-1/CHE_adm.zip
! mkdir -p data
! unzip CHE_adm.zip -d data
# Out:
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.
# A subdirectory or file -p already exists.
# Error occurred while processing: -p.
# A subdirectory or file data already exists.
# Error occurred while processing: data.
# 'unzip' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import pandas as pd
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt
import datetime
import os

# %% [markdown]
# Now we merge some numbers per canton (covid cases at some point in the past) with the shape files.

# %%
shape_file = 'data/CHE_adm1.shp'
switzerland = gpd.read_file(shape_file)
population_data = {
    'canton': ['Aargau', 'Appenzell Ausserrhoden', 'Appenzell Innerrhoden', 'Basel-Landschaft', 'Basel-Stadt',
               'Bern', 'Fribourg', 'Genève', 'Glarus', 'Graubünden', 'Jura', 'Lucerne',
               'Neuchâtel', 'Nidwalden', 'Obwalden', 'Schwyz', 'Schaffhausen', 'Solothurn',
               'Sankt Gallen', 'Thurgau', 'Ticino', 'Uri', 'Valais', 'Vaud', 'Zug', 'Zürich'],
    'population': [695.3, 55.7, 16.3, 291.3, 196.6, 1046.3, 325.2, 509.1, 40.7,
                   198.9, 73.8, 416.3, 177.3, 43.9, 38.4, 83.6, 162.6, 278.3,
                   516.7, 282.9, 353.3, 37, 349.2, 815.6, 130.2, 1553.6]
}

population_df = pd.DataFrame(population_data)

# Filter for Switzerland and merge with population data
switzerland = switzerland[switzerland['NAME_1'].isin(population_df['canton'])]
switzerland = switzerland.merge(population_df, left_on='NAME_1', right_on='canton')

# Plotting
fig, ax = plt.subplots(1, 1, figsize=(10, 10))
switzerland.boundary.plot(ax=ax, linewidth=1)  # Plot boundaries
switzerland.plot(column='population', ax=ax, legend=True,
                 legend_kwds={'label': "Population by Canton",
                              'orientation': "horizontal"},
                 cmap='OrRd', edgecolor='black')

# Title and show plot
plt.title('Population by Canton in Switzerland')
plt.show()

# %% [markdown]
# ### Excercise
# Draw another geoplot of Switzerland.

# %% [markdown]
# # Exercise 12 (continued)
# Investigate the merged datasets from yesterdays Exercise 12 using suitable graphical tools

# %%
data_2023 = pd.read_csv("./datasets/StatWiSo2023_raw.csv", sep=",")
data_2024 = pd.read_csv("./datasets/StatWiSo2024_raw.csv", sep=",")
data_2023['year'] = 2023
data_2024['year'] = 2024
data_merge_students = pd.concat([data_2023, data_2024], ignore_index=True)

# %%
data_merge_students = data_merge_students[data_merge_students['Bildschimzeit_in_Minuten'] <= 1440]
data_merge_students = data_merge_students[data_merge_students['Sport_in_Stunden'] <= 168]
data_merge_students
subject_mapping = {
'Religion': 'Religion',
'Wirtschaft & Recht': 'Wirtschaft und Recht',
'Physical Education': 'Sport',
'Philosophie': 'Philosophie',
'BG': 'Bildnerisches Gestalten',
'Wirtschaft und Recht': 'Wirtschaft und Recht',
'Mathe, Statistik, alle fächer die ich bei frau mühlemann gehabt hätte': 'Mathematik',
'Musik': 'Musik',
'Sport': 'Sport',
'Englisch': 'Englisch',
'Mathematik': 'Mathematik',
'Politikwissenschaft': 'Politikwissenschaft',
'Geschichte': 'Geschichte',
'Chemie': 'Chemie',
'*Passerelle: Physik': 'Physik',
'WR': 'Wirtschaft und Recht',
'WIRE': 'Wirtschaft und Recht',
'Wirtschaft': 'Wirtschaft und Recht',
'Physik': 'Physik',
'Biologie': 'Biologie',
'Psychologie und Pädagogik': 'Psychologie',
'Bg': 'Bildnerisches Gestalten',
'Mathematik \r\nWirtschaft': 'Mathematik',
'Deutsch': 'Deutsch',
'Wirtschaft + Recht': 'Wirtschaft und Recht',
'Bildnerisches Gestalten': 'Bildnerisches Gestalten',
'bwl': 'Wirtschaft und Recht',
'Spanisch': 'Spanisch',
'Wr': 'Wirtschaft und Recht',
'English': 'Englisch',
'Psychologie': 'Psychologie',
'Math': 'Mathematik',
'sport': 'Sport',
'math': 'Mathematik',
'Geografie': 'Geografie',
'Sport und Musik': 'Sport',
'Italienisch': 'Italienisch',
'Geschichte, Wirtschaft und Recht': 'Geschichte',
'Sport und WR': 'Sport',
'Franzoesisch': 'Französisch',
'spanisch': 'Spanisch',
'Rätoromanisch': 'Rätoromanisch',
'SWIR': 'Wirtschaft und Recht',
'(Bio-)Chemie': 'Chemie',
'VWL': 'Wirtschaft und Recht',
'SF Bio Chemie': 'Chemie',
'Geo': 'Geografie',
'GESCHICHTE': 'Geschichte',
'deutsch': 'Deutsch',
'Theater': 'Theater',
'Art': 'Bildnerisches Gestalten',
'Bildnerisches gestalten': 'Bildnerisches Gestalten',
'Politische Bildung': 'Politikwissenschaft',
'Kunst': 'Bildnerisches Gestalten',
'Mathe': 'Mathematik',
'mathematik': 'Mathematik',
'hatte keins': 'NA',
'Englisch, Mathematik': 'Englisch',
'SF Musik': 'Musik',
'Geographie': 'Geografie',
'W&R und Sport': 'Wirtschaft und Recht',
'EWR': 'Wirtschaft und Recht',
'Wirtschaft Geschichte': 'Wirtschaft und Recht',
'Digitale Kommunikation': 'Digitale Kommunikation',
'Technisches Gestalten': 'Bildnerisches Gestalten',
'Musik Kunstfach': 'Musik',
'Französisch': 'Französisch',
'Biologie und Chemie': 'Biologie',
'Religion, Psychologie': 'Religion',
'englisch': 'Englisch',
'Geschichte und Wirtschaft': 'Geschichte',
'Französich': 'Französisch',
'geschichte': 'Geschichte',
'sport, geschichte, Wirtschaft,': 'Sport',
'gar keins': 'NA',
'astrophysik': 'Physik',
'Wiertschaft und Recht': 'Wirtschaft und Recht',
'Informatik': 'Informatik',
'Sport, Geschichte': 'Sport',
'Geschichte und Recht': 'Geschichte',
'keines': 'NA',
'BWL': 'Wirtschaft und Recht',
'Schwerpunktfach Musik': 'Musik',
'Latein': 'Latein',
'Mein Lieblingsfach war Fremdsprache.': 'Fremdsprache',
'Anwendungen der Mathematik': 'Mathematik'
}
data_merge_students['Lieblingsfach'] = data_merge_students['Lieblingsfach'].replace(subject_mapping)
unique_subjects = data_merge_students['Lieblingsfach'].unique()

# %%
data_merge_students['Bildschimzeit_in_Minuten'].plot(kind="hist",fill=True,histtype='step',label='Bildschirmzeit', color = "skyblue", bins=30)
plt.show()

# %%
Bildschirmzeit = data_merge_students["Bildschimzeit_in_Minuten"]
Sport = data_merge_students["Sport_in_Stunden"]*60

# plotting first histogram
plt.hist(Bildschirmzeit, fill= True, histtype='step',label='Bildschirmzeit', color = "skyblue", bins=30, alpha =0.5)

# plotting second histogram
plt.hist(Sport, fill= True, histtype='step',label='Sport', color = "pink", bins=100, alpha =0.5)
plt.legend(title='Legende')
plt.xlim(0, 2000)
# Showing the plot using plt.show()
plt.show()

# %%
data_merge_students.plot(x='Bildschimzeit_in_Minuten',y='Sport_in_Stunden',kind="scatter",c='c')
plt.ylim(0, 30)
plt.show()

# %%
data_merge_students.plot(x='Kleidergroesse',y='Sport_in_Stunden',kind="scatter",c='c')
plt.ylim(0, 30)
plt.show()

# %%
# Wir definieren explizit die Sleep-Level, die geplottet werden sollen
exposure_list = [1, 2, 3, 4, 5]

# Figure + Subplots vorbereiten
n_exposure = len(exposure_list)
fig, axs = plt.subplots(1, n_exposure, figsize=(15, 5), sharex=True, sharey=True)

# Schleife über die Liste der Levels
for i, exposure in enumerate(exposure_list):
    exposure_data = sleep[sleep['Exposure'] == exposure] #wichtig- überprüfen nach welchen Daten ich filtere!
    axs[i].scatter(exposure_data['TotalSleep'], exposure_data['Dreaming'], color="b")
    axs[i].set_title(f'Exposure = {exposure}')
    axs[i].set_xlabel('TotalSleep')
    axs[i].set_ylabel('Dreaming')

plt.tight_layout()
plt.show()
